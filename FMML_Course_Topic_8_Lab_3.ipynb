# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmi-19pavani/FMML_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-15 17:24:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   155MB/s    in 0.4s
#
# 2024-04-15 17:24:12 (155 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10334   1209.1557v4  Several convex formulation methods have been p...  stat
# 29274  1708.09580v1  Two approaches are proposed for cross-pose fac...    cs
# 11827  1702.05575v2  We study the Stochastic Gradient Langevin Dyna...    cs
# 37940   1208.4271v2  We introduce a novel implementation in ANSI C ...  stat
# 24301   1307.5653v1  Parameter tuning is a common issue for many tr...    cs
# ...             ...                                                ...   ...
# 39149   1407.2044v2  In this paper we present a number of methods (...    cs
# 6710   1705.07562v2  We study the Stochastic Gradient Descent (SGD)...  stat
# 21503   0709.2989v1  Simulated annealing is a popular method for ap...  stat
# 5247    1204.1276v4  We obtain a tight distribution-specific charac...  stat
# 25745  1511.04670v1  In this work, we introduce Video Question Answ...    cs
#
#                                                    title  year  \
# 10334  Learning Model-Based Sparsity via Projected Gr...  2012
# 29274  Fast Landmark Localization with 3D Component R...  2017
# 11827  A Hitting Time Analysis of Stochastic Gradient...  2017
# 37940  Minerva and minepy: a C engine for the MINE su...  2012
# 24301  Online Tracking Parameter Adaptation based on ...  2013
# ...                                                  ...   ...
# 39149  Tracking Individual Targets in High Density Cr...  2014
# 6710   On the diffusion approximation of nonconvex st...  2017
# 21503  Simulated Annealing: Rigorous finite-time guar...  2007
# 5247   Distribution-Dependent Sample Complexity of La...  2012
# 25745  Uncovering Temporal Context for Video Question...  2015
#
#                                                 keywords
# 10334  [formulation, previously, statistical, estimat...
# 29274  [approaches, recognition, reconstruction, comp...
# 11827  [stochastic, algorithm, optimization, algorith...
# 37940  [introduce, implementation, algorithms, comput...
# 24301  [parameter, algorithms, parameter, algorithm, ...
# ...                                                  ...
# 39149  [automatic, individual, necessary, individuals...
# 6710   [stochastic, nonconvex, optimization, approxim...
# 21503  [simulated, annealing, approaching, optimizati...
# 5247   [distribution, characterization, complexity, c...
# 25745  [introduce, answering, recurrent, structures, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10334    [formulation, previously, statistical, estimat...
# 29274    [approaches, recognition, reconstruction, comp...
# 11827    [stochastic, algorithm, optimization, algorith...
# 37940    [introduce, implementation, algorithms, comput...
# 24301    [parameter, algorithms, parameter, algorithm, ...
#                                ...
# 22632    [estimation, statistical, community, unbounded...
# 15884    [interlingua, translation, languages, linguist...
# 18836    [efficient, debugging, cornerstone, activities...
# 14259    [crowdsourcing, effective, computation, unreli...
# 29229    [adjustment, centralized, incrementally, struc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8793 words.
# Out of those 4619 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="de519757-3201-49de-a73a-dacc815dcda0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de519757-3201-49de-a73a-dacc815dcda0")) {                    Plotly.newPlot(                        "de519757-3201-49de-a73a-dacc815dcda0",                        [{"x":["projected","structured","statistical","approximating","parameter","application","regularization","restricted","cumbersome","desirable","parameters","estimation","previously","algorithms","elaborate","generalized","accurately","estimating","minimizer","constraint","approximation","furthermore","heuristic","formulation","carefully","therefore","algorithm","components","performances","different","extractor","considers","experiments","component","landmarks","demonstrate","recognition","detection","reconstruction","hierarchical","approaches","including","reconstructs","recognizes","investigate","classifier","evaluated","segmentation","synthesized","extensive","convolutional","localization","approximate","minimization","empirical","learnability","suboptimal","optimization","appropriately","polynomial","classifiers","stochastic","arbitrary","population","integration","requirement","interface","libraries","variables","repository","available","introduce","computing","bioinformatics","properties","demonstrated","implementation","projectorg","information","multiplatform","footprint","availability","dependence","requirements","parallelization","microarray","benchmarks","pipelines","performance","adaptation","contributions","outperforms","experimental","evaluation","sensitive","complexity","efficiency","algorithmic","representative","techniques","manageable","crowdsourced","remarkable","achieving","framework","objectives","differential","addressing","qualities","efficient","classification","probabilistic","likelihood","experimentally","reformulating","alternative","processing","generative","retaining","discriminative","difficult","inference","functions","sequential","structure","precisely","producing","represent","enumerated","programming","functional","probability","constructs","graphical","infinitely","locations","nonparametrics","educational","numerical","remaining","inspiration","effective","leverages","correctness","submission","incorrect","education","engineering","partially","communication","technologies","clustering","substantially","technology","determine","platforms","prominently","comprises","solutions","automatic","mathematical","structures","assignments","automatically","assessments","instructor","questions","assignment","dimensionality","potential","regarding","dimensional","introduces","extremely","presented","utilizing","resistant","regression","knowledge","manifolds","reduction","distortions","dimension","improvement","significant","supported","partitioning","configurations","intermediate","constrained","environment","throughput","simulation","descriptors","developed","chemistry","primarily","predicting","particularly","compounds"],"y":[19,107,155,19,127,254,79,44,3,38,245,238,102,623,10,72,73,53,2,92,118,164,60,86,27,154,835,108,46,740,10,32,616,114,23,598,370,352,104,105,413,245,6,8,152,157,152,187,16,181,356,71,117,70,158,2,15,323,9,68,98,113,84,55,45,38,30,9,139,8,298,304,125,5,201,111,122,0,675,1,4,32,15,56,5,2,94,10,911,54,42,271,391,253,56,237,154,31,35,349,3,5,20,83,571,29,35,27,5,407,493,166,55,45,1,103,275,126,13,93,148,218,228,78,330,20,30,111,3,132,50,149,18,47,5,51,2,3,78,26,7,237,16,22,4,10,7,41,49,57,29,137,31,51,79,25,2,14,124,183,59,145,11,183,13,1,69,26,55,163,32,183,72,53,190,35,4,108,344,17,100,10,64,147,223,19,11,25,36,56,118,11,66,47,188,5,22,70,70,4],"type":"bar"},{"x":["projected","structured","statistical","approximating","parameter","app ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4619,), (4619, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>NoReC</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Norwegian</span> <span style=''>Review</span> <span style=''>Corpus</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Norwegian</span> <span style=''>Review</span> <span style=''>Corpus</span> <span style=''>(NoReC)</span> <span style=''>created</span> <span style=''>for</span> <span style=''>training</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.31249999999999994);'>evaluating</span> <span style=''>models</span> <span style=''>for</span> <span style=''>document</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.5471698113207546);'>sentiment</span> <span style=''>analysis</span> <span style=''>The</span> <span style=''>full</span> <span style=''>text</span> <span style=''>reviews</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.30693069306930687);'>collected</span> <span style=''>from</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Norwegian</span> <span style=''>news</span> <span style=''>sources</span> <span style=''>and</span> <span style=''>cover</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3062665489849956);'>different</span> <span style=''>domains</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>movies</span> <span style=''>video</span> <span style=''>games</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restaurants</span> <span style=''>music</span> <span style=''>and</span> <span style=''>theater</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>product</span> <span style=''>reviews</span> <span style=''>across</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6962025316455697);'>categories</span> <span style=''>Each</span> <span style=''>review</span> <span style=''>is</span> <span style=''>labeled</span> <span style=''>with</span> <span style=''>a</span> <span style=''>manually</span> <span style=''>assigned</span> <span style=''>score</span> <span style=''>of</span> <span style=''>1</span> <span style=''>6</span> <span style=''>as</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style=''>rating</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style=''>author</span> <span style=''>This</span> <span style=''>first</span> <span style=''>release</span> <span style=''>of</span> <span style=''>the</span> <span style=''>corpus</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>comprises</span> <span style=''>more</span> <span style=''>than</span> <span style=''>35000</span> <span style=''>reviews</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>using</span> <span style=''>the</span> <span style=''>CoNLL</span> <span style=''>U</span> <span style=''>format</span> <span style=''>pre</span> <span style='background-color:rgba(0, 255, 0, 0.6774193548387097);'>processed</span> <span style=''>using</span> <span style=''>UDPipe</span> <span style=''>along</span> <span style=''>with</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>set</span> <span style=''>of</span> <span style=''>metadata</span> <span style=''>The</span> <span style=''>work</span> <span style=''>reported</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Whenever</span> <span style=''>Learning</span> <span style=''>is</span> <span style=''>Possible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Universal</span> <span style=''>Learning</span> <span style=''>under</span> <span style=''>General</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initiates</span> <span style=''>a</span> <span style=''>general</span> <span style=''>study</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>without</span> <span style=''>the</span> <span style=''>iid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>starting</span> <span style=''>from</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>While</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>learning</span> <span style=''>theory</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>chosen</span> <span style=''>largely</span> <span style=''>for</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convenience</span> <span style=''>(eg</span> <span style=''>iid</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>ergodic)</span> <span style=''>in</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>a</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>only</span> <span style=''>on</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>and</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>implicit</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>itself</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>study</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>function</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>low</span> <span style=''>long</span> <span style=''>run</span> <span style=''>average</span> <span style=''>loss</span> <span style=''>for</span> <span style=''>any</span> <span style=''>target</span> <span style=''>function</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>follow</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>process</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.45945945945945943);'>divergence</span> <span style=''>as</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>unnormalized</span> <span style='background-color:rgba(255, 0, 0, 0.35146443514644354);'>statistical</span> <span style=''>models</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.45945945945945943);'>divergence</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>unnormalized</span> <span style='background-color:rgba(255, 0, 0, 0.35146443514644354);'>statistical</span> <span style=''>models</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>or</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.33809523809523817);'>variables</span> <span style=''>that</span> <span style=''>is</span> <span style=''>models</span> <span style=''>which</span> <span style=''>do</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>integrate</span> <span style=''>or</span> <span style=''>sum</span> <span style=''>to</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.442622950819672);'>respectively</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contrastive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>ratio</span> <span style=''>matching</span> <span style=''>and</span> <span style=''>score</span> <span style=''>matching</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>explain</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interconnection</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>Further</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>role</span> <span style=''>of</span> <span style=''>boosting</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Batched</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style=''>Kernel</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>While</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>has</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicability</span> <span style=''>has</span> <span style=''>been</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>problems</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>arising</span> <span style=''>from</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>settings</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>tackle</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>by</span> <span style=''>(1)</span> <span style=''>assuming</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>additive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>function</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>it</span> <span style=''>properly</span> <span style=''>for</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>BO</span> <span style=''>and</span> <span style=''>(2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>in</span> <span style=''>parallel</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>required</span> <span style=''>by</span> <span style=''>the</span> <span style=''>method</span> <span style=''>Our</span> <span style=''>novel</span> <span style=''>approach</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1223763785129847)
# 	experimental (0.1390964069726076)
# 	information (0.240128068303095)
# 	representation (0.13162575595873355)
# 	architecture (0.0839558875844895)
# 	segmentation (0.06652436855211669)
# 	different (0.2632515119174671)
# 	detection (0.12522234080398434)
# 	convolutional (0.12664532194948416)
# 	recognition (0.13162575595873355)
#
# Some Statistics words are:
# 	variables (0.1412770236299648)
# 	stochastic (0.13323278029160382)
# 	estimation (0.17998994469582705)
# 	algorithm (0.39316239316239315)
# 	theoretical (0.15434891905480141)
# 	distribution (0.1794871794871795)
# 	statistical (0.1623931623931624)
# 	inference (0.19054801407742583)
# 	dimensional (0.19658119658119658)
# 	regression (0.1910507792860734)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="966a488d-d64d-4a64-9479-b28e88a1fb37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("966a488d-d64d-4a64-9479-b28e88a1fb37")) {                    Plotly.newPlot(                        "966a488d-d64d-4a64-9479-b28e88a1fb37",                        [{"x":["projected","structured","statistical","approximating","parameter","application","regularization","restricted","cumbersome","desirable","parameters","estimation","previously","algorithms","elaborate","generalized","accurately","estimating","minimizer","constraint","approximation","furthermore","heuristic","formulation","carefully","therefore","algorithm","components","performances","different","extractor","considers","experiments","component","landmarks","demonstrate","recognition","detection","reconstruction","hierarchical","approaches","including","reconstructs","recognizes","investigate","classifier","evaluated","segmentation","synthesized","extensive","convolutional","localization","approximate","minimization","empirical","learnability","suboptimal","optimization","appropriately","polynomial","classifiers","stochastic","arbitrary","population","integration","requirement","interface","libraries","variables","repository","available","introduce","computing","bioinformatics","properties","demonstrated","implementation","projectorg","information","multiplatform","footprint","availability","dependence","requirements","parallelization","microarray","benchmarks","pipelines","performance","adaptation","contributions","outperforms","experimental","evaluation","sensitive","complexity","efficiency","algorithmic","representative","techniques","manageable","crowdsourced","remarkable","achieving","framework","objectives","differential","addressing","qualities","efficient","classification","probabilistic","likelihood","experimentally","reformulating","alternative","processing","generative","retaining","discriminative","difficult","inference","functions","sequential","structure","precisely","producing","represent","enumerated","programming","functional","probability","constructs","graphical","infinitely","locations","nonparametrics","educational","numerical","remaining","inspiration","effective","leverages","correctness","submission","incorrect","education","engineering","partially","communication","technologies","clustering","substantially","technology","determine","platforms","prominently","comprises","solutions","automatic","mathematical","structures","assignments","automatically","assessments","instructor","questions","assignment","dimensionality","potential","regarding","dimensional","introduces","extremely","presented","utilizing","resistant","regression","knowledge","manifolds","reduction","distortions","dimension","improvement","significant","supported","partitioning","configurations","intermediate","constrained","environment","throughput","simulation","descriptors","developed","chemistry","primarily","predicting","particularly","compounds","applications","demonstrates","plausibility","providing","transformative","prediction","computational","molecular","inception","architecture","chemception","solvation","periodicity","fingerprints","molecules","performed","additional","perceptron","unsupervised","performing","variational","distribution","degeneracy","processes","competitive","autoencoders","autoencoder","interpretable","synthetic","intuition","visualizations","manifests","regularisation","preceding","confirmed","interestingly","condition","trajectory","consonant","characters","represents","realization","interpret","conditions","extracted","consonants","comparison","phenomenon","attributes","antibiotics","stochasticity","subpopulations","reconstructing","trajectories","re ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	projectorg
# 	chemception
# 	solvation
# 	replicate
# 	epidemics
# 	purchasing
# 	integrable
# 	eigenvalue
# 	generalising
# 	reversing
# 	geosciences
# 	stringent
# 	bhattacharyya
# 	practitioner
# 	epidemiology
# 	normalising
# 	discriminators
# 	notations
# 	unpenalized
# 	decomposability
# Some words which never appear in Statistics papers:
# 	consonant
# 	trustworthy
# 	competency
# 	susceptibility
# 	syllogism
# 	quantifiers
# 	commonsense
# 	accordance
# 	transcriptions
# 	stockholm
# 	lemmatization
# 	inflection
# 	syntactic
# 	colorings
# 	undefined
# 	forgeries
# 	inheriting
# 	automaton
# 	steerable
# 	rotationally

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.055394298634239e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
